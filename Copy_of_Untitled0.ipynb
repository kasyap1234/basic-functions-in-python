# %%
# %% [markdown]
# # Assignment 1 - Python Basics Practice
# 
# *This assignment is a part of the course ["Data Analysis with Python: Zero to Pandas"](https://jovian.ml/learn/data-analysis-with-python-zero-to-pandas)*
# 
# In this assignment, you'll get to practice some of the concepts and skills covered in the following notebooks:
# 
# 1. [First Steps with Python and Jupyter](https://jovian.ml/aakashns/first-steps-with-python)
# 2. [A Quick Tour of Variables and Data Types](https://jovian.ml/aakashns/python-variables-and-data-types)
# 3. [Branching using Conditional Statements and Loops](https://jovian.ml/aakashns/python-branching-and-loops)
# 
# 
# As you go through this notebook, you will find the symbol **???** in certain places. To complete this assignment, you must replace all the **???** with appropriate values, expressions or statements to ensure that the notebook runs properly end-to-end. 
# 
# **Guidelines**
# 
# 1. Make sure to run all the code cells, otherwise you may get errors like `NameError` for undefined variables.
# 2. Do not change variable names, delete cells or disturb other existing code. It may cause problems during evaluation.
# 3. In some cases, you may need to add some code cells or new statements before or after the line of code containing the **???**. 
# 4. Since you'll be using a free online service for code execution, save your work by running `jovian.commit` at regular intervals.
# 5. Questions marked **(Optional)** will not be considered for evaluation, and can be skipped. They are for your learning.
# 6. If you are stuck, you can ask for help on the course forum. Post errors, ask for hints and help others, but **please don't share the full solution answer code** to give others a chance to write the code themselves.
# 7. After submission your code will be tested with some hidden test cases. Make sure to test your code exhaustively to cover all edge cases.
# 
# 
# Important Links:
# 
# * Make submissions here: https://jovian.ml/learn/data-analysis-with-python-zero-to-pandas/assignment/assignment-1-python-basics-practice
# 
# * Get help on the community forum: https://jovian.ml/forum/t/assignment-1-python-practice/7761 . You can get help with errors or ask for hints, but **please don't ask for or share the full working answer code** on the forum.

# %% [markdown]
# ### How to Run the Code and Save Your Work
# 
# **Option 1: Running using free online resources (1-click, recommended)**: Click the **Run** button at the top of this page and select **Run on Binder**. You can also select "Run on Colab" or "Run on Kaggle", but you'll need to create an account on [Google Colab](https://colab.research.google.com) or [Kaggle](https://kaggle.com) to use these platforms.
# 
# 
# **Option 2: Running on your computer locally**: To run the code on your computer locally, you'll need to set up [Python](https://www.python.org) & [Conda](https://docs.conda.io/projects/conda/en/latest/user-guide/install/), download the notebook and install the required libraries. Click the **Run** button at the top of this page, select the **Run Locally** option, and follow the instructions.
# 
# **Saving your work**: You can save a snapshot of the assignment to your [Jovian](https://jovian.ai) profile, so that you can access it later and continue your work. Keep saving your work by running `jovian.commit` from time to time.

# %% [code] {"jupyter":{"outputs_hidden":false},"execution":{"iopub.status.busy":"2021-09-11T15:29:40.655081Z","iopub.execute_input":"2021-09-11T15:29:40.656025Z","iopub.status.idle":"2021-09-11T15:30:20.204691Z","shell.execute_reply.started":"2021-09-11T15:29:40.655973Z","shell.execute_reply":"2021-09-11T15:30:20.20352Z"}}
# Install the library
# !pip install jovian --upgrade --quiet

# %% [code] {"jupyter":{"outputs_hidden":false},"execution":{"iopub.status.busy":"2021-09-11T15:30:20.207261Z","iopub.execute_input":"2021-09-11T15:30:20.207632Z","iopub.status.idle":"2021-09-11T15:30:20.231836Z","shell.execute_reply.started":"2021-09-11T15:30:20.207589Z","shell.execute_reply":"2021-09-11T15:30:20.22987Z"}}
# Import it
import jovian

# %% [code] {"jupyter":{"outputs_hidden":false},"execution":{"iopub.status.busy":"2021-09-11T15:30:20.233416Z","iopub.status.idle":"2021-09-11T15:30:20.233763Z","shell.execute_reply.started":"2021-09-11T15:30:20.23359Z","shell.execute_reply":"2021-09-11T15:30:20.233606Z"}}
project_name='python-practice-assignment'

# %% [code] {"jupyter":{"outputs_hidden":false},"execution":{"iopub.status.busy":"2021-09-11T15:30:20.234876Z","iopub.status.idle":"2021-09-11T15:30:20.235316Z","shell.execute_reply.started":"2021-09-11T15:30:20.235105Z","shell.execute_reply":"2021-09-11T15:30:20.235129Z"}}
# Capture and upload a snapshot
jovian.commit(project=project_name, privacy='secret', evironment=None)

# %% [markdown]
# You'll be asked to provide an API Key, to securely upload the notebook to your Jovian.ml account. You can get the API key from your Jovian.ml profile page after logging in / signing up. See the docs for details: https://jovian.ml/docs/user-guide/upload.html . The privacy of your assignment notebook is set to *Secret*, so that you can the evlauators can access it, but it will not shown on your public profile to other users.

# %% [markdown]
# ## Problem 1 - Variables and Data Types
# 
# **Q1: Assign your name to the variable `name`.**

# %% [code] {"jupyter":{"outputs_hidden":false}}
name = 'Kasyap'

# %% [markdown]
# **Q2: Assign your age (real or fake) to the variable `age`.**

# %% [code] {"jupyter":{"outputs_hidden":false}}
age = 18

# %% [markdown]
# **Q3: Assign a boolean value to the variable `has_android_phone`.**

# %% [code] {"jupyter":{"outputs_hidden":false}}
has_android_phone = True

# %% [markdown]
# You can check the values of these variables by running the next cell.

# %% [code] {"jupyter":{"outputs_hidden":false}}
name, age, has_android_phone

# %% [markdown]
# **Q4: Create a dictionary `person` with keys `"Name"`, `"Age"`, `"HasAndroidPhone"` and values using the variables defined above.**

# %% [code] {"execution":{"iopub.status.busy":"2021-09-11T13:10:49.196644Z","iopub.execute_input":"2021-09-11T13:10:49.197672Z","iopub.status.idle":"2021-09-11T13:10:49.221777Z","shell.execute_reply.started":"2021-09-11T13:10:49.197486Z","shell.execute_reply":"2021-09-11T13:10:49.220811Z"},"jupyter":{"outputs_hidden":false}}
person = {'Name' : 'Kasyap ','Age' : '18', "HasAndroidPhone": 
        'True'}

# %% [markdown]
# Let's use the `person` dictionary to print a nice message.

# %% [code] {"execution":{"iopub.status.busy":"2021-09-11T13:11:32.901261Z","iopub.execute_input":"2021-09-11T13:11:32.902086Z","iopub.status.idle":"2021-09-11T13:11:32.910364Z","shell.execute_reply.started":"2021-09-11T13:11:32.902024Z","shell.execute_reply":"2021-09-11T13:11:32.909239Z"},"jupyter":{"outputs_hidden":false}}
print("{} is aged {}, and owns an {}.".format(
    person["Name"], 
    person["Age"], 
    "Android phone" if person["HasAndroidPhone"] else "iPhone"
))

# %% [markdown]
# **Q4b (Optional): Use a `for` loop to display the `type` of each value stored against each key in `person`.**
# 
# Here's the expected output for the key `"Name"`: 
# 
# ```
# The key "Name" has the value "Derek" of the type "<class 'str'>"
# ```

# %% [code] {"jupyter":{"outputs_hidden":false}}
# this is optional


# %% [markdown]
# Now that you've solved one problem, it would be a good idea to record a snapshot of your notebook.

# %% [code] {"jupyter":{"outputs_hidden":false}}
jovian.commit(project=project_name,environment=None)

# %% [markdown]
# ## Problem 2 - Working with Lists
# 
# **Q5: Create a list containing the following 3 elements:**
# 
# * your favorite color
# * the number of pets you have
# * a boolean value describing whether you have previous programming experience

# %% [code] {"execution":{"iopub.status.busy":"2021-09-11T15:08:50.088258Z","iopub.execute_input":"2021-09-11T15:08:50.089124Z","iopub.status.idle":"2021-09-11T15:08:50.094485Z","shell.execute_reply.started":"2021-09-11T15:08:50.089076Z","shell.execute_reply":"2021-09-11T15:08:50.093513Z"},"jupyter":{"outputs_hidden":false}}
my_list =['blue',0,True]

# %% [markdown]
# Let's see what the list looks like:

# %% [code] {"execution":{"iopub.status.busy":"2021-09-11T15:08:52.663311Z","iopub.execute_input":"2021-09-11T15:08:52.663624Z","iopub.status.idle":"2021-09-11T15:08:52.672188Z","shell.execute_reply.started":"2021-09-11T15:08:52.663596Z","shell.execute_reply":"2021-09-11T15:08:52.671065Z"},"jupyter":{"outputs_hidden":false}}
my_list

# %% [markdown]
# **Q6: Complete the following `print` and `if` statements by accessing the appropriate elements from `my_list`.**
# 
# *Hint*: Use the list indexing notation `[]`.

# %% [code] {"execution":{"iopub.status.busy":"2021-09-11T15:08:54.626828Z","iopub.execute_input":"2021-09-11T15:08:54.627101Z","iopub.status.idle":"2021-09-11T15:08:54.633355Z","shell.execute_reply.started":"2021-09-11T15:08:54.627074Z","shell.execute_reply":"2021-09-11T15:08:54.632002Z"},"jupyter":{"outputs_hidden":false}}
print('My favorite color is',my_list[0])

# %% [code] {"execution":{"iopub.status.busy":"2021-09-11T15:08:58.975308Z","iopub.execute_input":"2021-09-11T15:08:58.975628Z","iopub.status.idle":"2021-09-11T15:08:58.982051Z","shell.execute_reply.started":"2021-09-11T15:08:58.975599Z","shell.execute_reply":"2021-09-11T15:08:58.981101Z"},"jupyter":{"outputs_hidden":false}}
print('I have {} pet(s).'.format(0))

# %% [code] {"execution":{"iopub.status.busy":"2021-09-11T15:09:14.111529Z","iopub.execute_input":"2021-09-11T15:09:14.112505Z","iopub.status.idle":"2021-09-11T15:09:14.118688Z","shell.execute_reply.started":"2021-09-11T15:09:14.112456Z","shell.execute_reply":"2021-09-11T15:09:14.117753Z"},"jupyter":{"outputs_hidden":false}}
if True:
    print("I have previous programming experience")
else:
    print("I do not have previous programming experience")

# %% [markdown]
# **Q7: Add your favorite single digit number to the end of the list using the appropriate list method.**

# %% [code] {"jupyter":{"outputs_hidden":false}}
my_list.append(3)

# %% [markdown]
# Let's see if the number shows up in the list.

# %% [code] {"jupyter":{"outputs_hidden":false}}
my_list

# %% [markdown]
# **Q8: Remove the first element of the list, using the appropriate list method.**
# 
# *Hint*: Check out methods of list here: https://www.w3schools.com/python/python_ref_list.asp

# %% [code] {"execution":{"iopub.status.busy":"2021-09-11T15:10:06.977867Z","iopub.execute_input":"2021-09-11T15:10:06.978921Z","iopub.status.idle":"2021-09-11T15:10:06.986166Z","shell.execute_reply.started":"2021-09-11T15:10:06.978863Z","shell.execute_reply":"2021-09-11T15:10:06.984857Z"},"jupyter":{"outputs_hidden":false}}
my_list.pop(0)

# %% [code] {"execution":{"iopub.status.busy":"2021-09-11T15:10:12.457161Z","iopub.execute_input":"2021-09-11T15:10:12.458037Z","iopub.status.idle":"2021-09-11T15:10:12.463905Z","shell.execute_reply.started":"2021-09-11T15:10:12.457983Z","shell.execute_reply":"2021-09-11T15:10:12.462863Z"},"jupyter":{"outputs_hidden":false}}
my_list

# %% [markdown]
# **Q9: Complete the `print` statement below to display the number of elements in `my_list`.**

# %% [code] {"execution":{"iopub.status.busy":"2021-09-11T15:10:34.922729Z","iopub.execute_input":"2021-09-11T15:10:34.923691Z","iopub.status.idle":"2021-09-11T15:10:34.929308Z","shell.execute_reply.started":"2021-09-11T15:10:34.923638Z","shell.execute_reply":"2021-09-11T15:10:34.928502Z"},"jupyter":{"outputs_hidden":false}}
print("The list has {} elements.".format(len(my_list)))

# %% [markdown]
# Well done, you're making good progress! Save your work before continuing

# %% [code] {"execution":{"iopub.status.busy":"2021-09-11T15:10:39.175172Z","iopub.execute_input":"2021-09-11T15:10:39.17548Z","iopub.status.idle":"2021-09-11T15:10:39.193075Z","shell.execute_reply.started":"2021-09-11T15:10:39.175448Z","shell.execute_reply":"2021-09-11T15:10:39.191673Z"},"jupyter":{"outputs_hidden":false}}
jovian.commit(project=project_name,environment=None)

# %% [markdown]
# ## Problem 3 - Conditions and loops
# 
# **Q10: Calculate and display the sum of all the numbers divisible by 7 between 18 and 534 i.e. `21+28+35+...+525+532`**.
# 
# *Hint*: One way to do this is to loop over a `range` using `for` and use an `if` statement inside it.

# %% [code] {"execution":{"iopub.status.busy":"2021-09-11T15:12:39.924103Z","iopub.execute_input":"2021-09-11T15:12:39.924989Z","iopub.status.idle":"2021-09-11T15:12:39.930151Z","shell.execute_reply.started":"2021-09-11T15:12:39.92494Z","shell.execute_reply":"2021-09-11T15:12:39.929445Z"},"jupyter":{"outputs_hidden":false}}
# store the final answer in this variable
sum_of_numbers = 0

# perform the calculation here
for i in range(7,534): 
    if i%7==0: 
        sum_of_numbers+=i

# %% [code] {"execution":{"iopub.status.busy":"2021-09-11T15:12:43.947867Z","iopub.execute_input":"2021-09-11T15:12:43.948859Z","iopub.status.idle":"2021-09-11T15:12:43.955533Z","shell.execute_reply.started":"2021-09-11T15:12:43.948816Z","shell.execute_reply":"2021-09-11T15:12:43.954309Z"},"jupyter":{"outputs_hidden":false}}
print('The sum of all the numbers divisible by 7 between 18 and 534 is', sum_of_numbers)

# %% [markdown]
# If you are not able to figure out the solution to this problem, you can ask for hints on the community forum: https://jovian.ml/forum/t/assignment-1-python-practice/7761 . Remember to save your work before moving forward.

# %% [code] {"jupyter":{"outputs_hidden":false}}
jovian.commit(project=project_name,environment=None)

# %% [markdown]
# ## Problem 4 - Flying to the Bahamas
# 
# **Q11: A travel company wants to fly a plane to the Bahamas. Flying the plane costs 5000 dollars. So far, 29 people have signed up for the trip. If the company charges 200 dollars per ticket, what is the profit made by the company?**
# 
# Fill in values or arithmetic expressions for the variables below.

# %% [code] {"execution":{"iopub.status.busy":"2021-09-11T15:14:45.047891Z","iopub.execute_input":"2021-09-11T15:14:45.048186Z","iopub.status.idle":"2021-09-11T15:14:45.05176Z","shell.execute_reply.started":"2021-09-11T15:14:45.04816Z","shell.execute_reply":"2021-09-11T15:14:45.050983Z"},"jupyter":{"outputs_hidden":false}}
cost_of_flying_plane = 5000

# %% [code] {"execution":{"iopub.status.busy":"2021-09-11T15:14:43.327883Z","iopub.execute_input":"2021-09-11T15:14:43.328189Z","iopub.status.idle":"2021-09-11T15:14:43.333663Z","shell.execute_reply.started":"2021-09-11T15:14:43.32816Z","shell.execute_reply":"2021-09-11T15:14:43.332487Z"},"jupyter":{"outputs_hidden":false}}
number_of_passengers = 29

# %% [code] {"execution":{"iopub.status.busy":"2021-09-11T15:14:47.483906Z","iopub.execute_input":"2021-09-11T15:14:47.484237Z","iopub.status.idle":"2021-09-11T15:14:47.488504Z","shell.execute_reply.started":"2021-09-11T15:14:47.484202Z","shell.execute_reply":"2021-09-11T15:14:47.487623Z"},"jupyter":{"outputs_hidden":false}}
price_of_ticket = 200

# %% [code] {"execution":{"iopub.status.busy":"2021-09-11T15:14:49.440605Z","iopub.execute_input":"2021-09-11T15:14:49.441497Z","iopub.status.idle":"2021-09-11T15:14:49.446068Z","shell.execute_reply.started":"2021-09-11T15:14:49.441456Z","shell.execute_reply":"2021-09-11T15:14:49.445189Z"},"jupyter":{"outputs_hidden":false}}
profit = number_of_passengers*price_of_ticket - cost_of_flying_plane

# %% [code] {"execution":{"iopub.status.busy":"2021-09-11T15:14:52.005969Z","iopub.execute_input":"2021-09-11T15:14:52.007089Z","iopub.status.idle":"2021-09-11T15:14:52.012897Z","shell.execute_reply.started":"2021-09-11T15:14:52.007046Z","shell.execute_reply":"2021-09-11T15:14:52.011535Z"},"jupyter":{"outputs_hidden":false}}
print('The company makes of a profit of {} dollars'.format(profit))

# %% [markdown]
# **Q11b (Optional): Out of the 29 people who took the flight, only 12 buy tickets to return from the Bahamas on the same plane. If the flying the plane back also costs 5000 dollars, and does the company make an overall profit or loss? The company charges the same fee of 200 dollars per ticket for the return flight.**
# 
# Use an `if` statement to display the result.

# %% [code] {"jupyter":{"outputs_hidden":false}}
# this is optional


# %% [code] {"jupyter":{"outputs_hidden":false}}
# this is optional

# %% [markdown]
# Great work so far! Want to take a break? Remember to save and upload your notebook to record your progress.

# %% [code] {"jupyter":{"outputs_hidden":false}}
jovian.commit(project=project_name,environment=None)

# %% [markdown]
# ## Problem 5 - Twitter Sentiment Analysis
# 
# Are your ready to perform some *Data Analysis with Python*? In this problem, we'll analyze some fictional tweets and find out whether the overall sentiment of Twitter users is happy or sad. This is a simplified version of an important real world problem called *sentiment analysis*.
# 
# Before we begin, we need a list of tweets to analyze. We're picking a small number of tweets here, but the exact same analysis can also be done for thousands, or even millions of tweets. The collection of data that we perform analysis on is often called a *dataset*.

# %% [code] {"execution":{"iopub.status.busy":"2021-09-11T15:15:54.501564Z","iopub.execute_input":"2021-09-11T15:15:54.501897Z","iopub.status.idle":"2021-09-11T15:15:54.507582Z","shell.execute_reply.started":"2021-09-11T15:15:54.501869Z","shell.execute_reply":"2021-09-11T15:15:54.506623Z"},"jupyter":{"outputs_hidden":false}}
tweets = [
    "Wow, what a great day today!! #sunshine",
    "I feel sad about the things going on around us. #covid19",
    "I'm really excited to learn Python with @JovianML #zerotopandas",
    "This is a really nice song. #linkinpark",
    "The python programming language is useful for data science",
    "Why do bad things happen to me?",
    "Apple announces the release of the new iPhone 12. Fans are excited.",
    "Spent my day with family!! #happy",
    "Check out my blog post on common string operations in Python. #zerotopandas",
    "Freecodecamp has great coding tutorials. #skillup"
]

# %% [markdown]
# Let's begin by answering a very simple but important question about our dataset.
# 
# **Q12: How many tweets does the dataset contain?**

# %% [code] {"execution":{"iopub.status.busy":"2021-09-11T15:15:56.666364Z","iopub.execute_input":"2021-09-11T15:15:56.66737Z","iopub.status.idle":"2021-09-11T15:15:56.672039Z","shell.execute_reply.started":"2021-09-11T15:15:56.667298Z","shell.execute_reply":"2021-09-11T15:15:56.67095Z"},"jupyter":{"outputs_hidden":false}}
number_of_tweets = len(tweets)

# %% [markdown]
# Let's create two lists of words: `happy_words` and `sad_words`. We will use these to check if a tweet is happy or sad.

# %% [code] {"execution":{"iopub.status.busy":"2021-09-11T15:18:40.861562Z","iopub.execute_input":"2021-09-11T15:18:40.86183Z","iopub.status.idle":"2021-09-11T15:18:40.866207Z","shell.execute_reply.started":"2021-09-11T15:18:40.861804Z","shell.execute_reply":"2021-09-11T15:18:40.865307Z"},"jupyter":{"outputs_hidden":false}}
happy_words = ['great', 'excited', 'happy', 'nice', 'wonderful', 'amazing', 'good', 'best']

# %% [code] {"execution":{"iopub.status.busy":"2021-09-11T15:18:42.593231Z","iopub.execute_input":"2021-09-11T15:18:42.593528Z","iopub.status.idle":"2021-09-11T15:18:42.597797Z","shell.execute_reply.started":"2021-09-11T15:18:42.5935Z","shell.execute_reply":"2021-09-11T15:18:42.597071Z"},"jupyter":{"outputs_hidden":false}}
sad_words = ['sad', 'bad', 'tragic', 'unhappy', 'worst']

# %% [markdown]
# To identify whether a tweet is happy, we can simply check if contains any of the words from `happy_words`. Here's an example:

# %% [code] {"execution":{"iopub.status.busy":"2021-09-11T15:18:45.639295Z","iopub.execute_input":"2021-09-11T15:18:45.640149Z","iopub.status.idle":"2021-09-11T15:18:45.644783Z","shell.execute_reply.started":"2021-09-11T15:18:45.640106Z","shell.execute_reply":"2021-09-11T15:18:45.643573Z"},"jupyter":{"outputs_hidden":false}}
sample_tweet = tweets[0]

# %% [code] {"execution":{"iopub.status.busy":"2021-09-11T15:18:47.406806Z","iopub.execute_input":"2021-09-11T15:18:47.407133Z","iopub.status.idle":"2021-09-11T15:18:47.413439Z","shell.execute_reply.started":"2021-09-11T15:18:47.407098Z","shell.execute_reply":"2021-09-11T15:18:47.412569Z"},"jupyter":{"outputs_hidden":false}}
sample_tweet

# %% [code] {"execution":{"iopub.status.busy":"2021-09-11T15:18:50.081005Z","iopub.execute_input":"2021-09-11T15:18:50.081642Z","iopub.status.idle":"2021-09-11T15:18:50.087928Z","shell.execute_reply.started":"2021-09-11T15:18:50.081596Z","shell.execute_reply":"2021-09-11T15:18:50.086607Z"},"jupyter":{"outputs_hidden":false}}
is_tweet_happy = False

# Get a word from happy_words
for word in happy_words:
    # Check if the tweet contains the word
    if word in sample_tweet:
        # Word found! Mark the tweet as happy
        is_tweet_happy = True

# %% [markdown]
# Do you understand what we're doing above? 
# 
# > For each word in the list of happy words, we check if is a part of the selected tweet. If the word is indded a part of the tweet, we set the variable `is_tweet_happy` to `True`.

# %% [code] {"execution":{"iopub.status.busy":"2021-09-11T15:18:52.394469Z","iopub.execute_input":"2021-09-11T15:18:52.394829Z","iopub.status.idle":"2021-09-11T15:18:52.401321Z","shell.execute_reply.started":"2021-09-11T15:18:52.394796Z","shell.execute_reply":"2021-09-11T15:18:52.400517Z"},"jupyter":{"outputs_hidden":false}}
is_tweet_happy

# %% [markdown]
# **Q13: Determine the number of tweets in the dataset that can be classified as happy.**
# 
# *Hint*: You'll need to use a loop inside another loop to do this. Use the code from the example shown above.

# %% [code] {"execution":{"iopub.status.busy":"2021-09-11T15:18:54.960482Z","iopub.execute_input":"2021-09-11T15:18:54.960802Z","iopub.status.idle":"2021-09-11T15:18:54.966917Z","shell.execute_reply.started":"2021-09-11T15:18:54.960773Z","shell.execute_reply":"2021-09-11T15:18:54.965692Z"},"jupyter":{"outputs_hidden":false}}
# store the final answer in this variable
number_of_happy_tweets = 0

# perform the calculations here
for word in happy_words: 
    for sent in tweets: 
        if word in sent: 
            number_of_happy_tweets+=1

# %% [code] {"execution":{"iopub.status.busy":"2021-09-11T15:18:57.484552Z","iopub.execute_input":"2021-09-11T15:18:57.484884Z","iopub.status.idle":"2021-09-11T15:18:57.492474Z","shell.execute_reply.started":"2021-09-11T15:18:57.484854Z","shell.execute_reply":"2021-09-11T15:18:57.49159Z"},"jupyter":{"outputs_hidden":false}}
print("Number of happy tweets:", number_of_happy_tweets)

# %% [markdown]
# If you are not able to figure out the solution to this problem, you can ask for hints on the community forum: https://jovian.ml/forum/t/assignment-1-python-practice/7761 . Also try adding `print` statements inside your loops to inspect variables and make sure your logic is correct.

# %% [markdown]
# **Q14: What fraction of the total number of tweets are happy?**
# 
# For example, if 2 out of 10 tweets are happy, then the answer is `2/10` i.e. `0.2`.

# %% [code] {"execution":{"iopub.status.busy":"2021-09-11T15:19:26.864077Z","iopub.execute_input":"2021-09-11T15:19:26.864382Z","iopub.status.idle":"2021-09-11T15:19:26.868978Z","shell.execute_reply.started":"2021-09-11T15:19:26.864352Z","shell.execute_reply":"2021-09-11T15:19:26.868163Z"},"jupyter":{"outputs_hidden":false}}
happy_fraction = number_of_happy_tweets/len(tweets)

# %% [code] {"execution":{"iopub.status.busy":"2021-09-11T15:19:29.032592Z","iopub.execute_input":"2021-09-11T15:19:29.03315Z","iopub.status.idle":"2021-09-11T15:19:29.038754Z","shell.execute_reply.started":"2021-09-11T15:19:29.033118Z","shell.execute_reply":"2021-09-11T15:19:29.038043Z"},"jupyter":{"outputs_hidden":false}}
print("The fraction of happy tweets is:", happy_fraction)

# %% [markdown]
# To identify whether a tweet is sad, we can simply check if contains any of the words from `sad_words`.
# 
# **Q15: Determine the number of tweets in the dataset that can be classified as sad.**

# %% [code] {"execution":{"iopub.status.busy":"2021-09-11T15:20:36.814149Z","iopub.execute_input":"2021-09-11T15:20:36.81518Z","iopub.status.idle":"2021-09-11T15:20:36.820667Z","shell.execute_reply.started":"2021-09-11T15:20:36.815125Z","shell.execute_reply":"2021-09-11T15:20:36.819558Z"},"jupyter":{"outputs_hidden":false}}
# store the final answer in this variable
number_of_sad_tweets = 0

# perform the calculations here
for word in sad_words: 
    for i in tweets: 
        if word in i: 
            number_of_sad_tweets+=1

# %% [code] {"execution":{"iopub.status.busy":"2021-09-11T15:20:40.222865Z","iopub.execute_input":"2021-09-11T15:20:40.223796Z","iopub.status.idle":"2021-09-11T15:20:40.229676Z","shell.execute_reply.started":"2021-09-11T15:20:40.22375Z","shell.execute_reply":"2021-09-11T15:20:40.228659Z"},"jupyter":{"outputs_hidden":false}}
print("Number of sad tweets:", number_of_sad_tweets)

# %% [markdown]
# **Q16: What fraction of the total number of tweets are sad?**

# %% [code] {"execution":{"iopub.status.busy":"2021-09-11T15:20:59.916285Z","iopub.execute_input":"2021-09-11T15:20:59.916604Z","iopub.status.idle":"2021-09-11T15:20:59.920918Z","shell.execute_reply.started":"2021-09-11T15:20:59.916576Z","shell.execute_reply":"2021-09-11T15:20:59.920241Z"},"jupyter":{"outputs_hidden":false}}
sad_fraction = number_of_sad_tweets/len(tweets)

# %% [code] {"execution":{"iopub.status.busy":"2021-09-11T15:21:01.636559Z","iopub.execute_input":"2021-09-11T15:21:01.637047Z","iopub.status.idle":"2021-09-11T15:21:01.642611Z","shell.execute_reply.started":"2021-09-11T15:21:01.637007Z","shell.execute_reply":"2021-09-11T15:21:01.641775Z"},"jupyter":{"outputs_hidden":false}}
print("The fraction of sad tweets is:", sad_fraction)

# %% [markdown]
# The rest of this problem is optional. Let's save your work before continuing.

# %% [code] {"jupyter":{"outputs_hidden":false}}
jovian.commit(project=project_name,environment=None)

# %% [markdown]
# Great work, even with some basic analysis, we already know a lot about the sentiment of the tweets given to us. Let us now define a metric called "sentiment score", to summarize the overall sentiment of the tweets.
# 

# Make a submission here by filling the submission form: https://jovian.ml/learn/data-analysis-with-python-zero-to-pandas/assignment/assignment-1-python-basics-practice

# %% [code] {"jupyter":{"outputs_hidden":false},"execution":{"iopub.status.busy":"2021-09-11T15:29:06.419654Z","iopub.execute_input":"2021-09-11T15:29:06.419939Z","iopub.status.idle":"2021-09-11T15:29:06.437882Z","shell.execute_reply.started":"2021-09-11T15:29:06.419911Z","shell.execute_reply":"2021-09-11T15:29:06.436594Z"}}
jovian.commit(project=project_name,environment=None)
# Out:
# [jovian] Detected Colab notebook...
# [jovian] Error: jovian.commit doesn't work on Colab unless the notebook was created and executed from Jovian.
# Make sure to run the first code cell at the top after executing from Jovian.
# Alternatively, you can download this notebook and upload it manually to Jovian.
# Learn more: https://jovian.ai/docs/user-guide/run.html#run-on-colab
# Kasyap  is aged 18, and owns an Android phone.
# [jovian] Detected Colab notebook...
# [jovian] Error: jovian.commit doesn't work on Colab unless the notebook was created and executed from Jovian.
# Make sure to run the first code cell at the top after executing from Jovian.
# Alternatively, you can download this notebook and upload it manually to Jovian.
# Learn more: https://jovian.ai/docs/user-guide/run.html#run-on-colab
# My favorite color is blue
# I have 0 pet(s).
# I have previous programming experience
# The list has 3 elements.
# [jovian] Detected Colab notebook...
# ...
